# %%
import pandas as pd
import re

# %%
df = pd.read_csv('all_csv/Taraz_all.csv')
df
# Out:
#                    date                                            message  \
# 0   2024-10-27T18:50:36                                            Микрдан
# 1   2024-10-27T18:50:31                                50 Ден 70 колеминде
# 2   2024-10-27T18:50:04  1 2 болмели кв керек еди узак мерзимге семейны...
# 3   2024-10-27T18:48:22                                  Ассалаумагалеикум
# 4   2024-10-25T11:11:46             Жас отбасы, 2 кишкентай балапандарымен
# ..                  ...                                                ...
# 56  2024-07-13T08:35:00                                    Микраион дардан
# 57  2024-07-13T08:34:41                       Саламатсыздарма ищу квартира
# 58  2024-07-01T08:27:19  Поселениеге 3 кыз керек.барлык жагдайы жасалга...
# 59  2024-05-11T20:53:14                        Поселение 3 комнат квартира
# 60  2024-04-06T07:46:24  Подселение в 2х комнатную кв . Проживание с ХО...
#
#                                          channel_name
# 0   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 1   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 2   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 3   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 4   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# ..                                                ...
# 56  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 57  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 58  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 59  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 60  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
#
# [61 rows x 3 columns]

# %%
# Function to clean each message
def clean_text(text):
    # Keep only Cyrillic letters, numbers, and spaces
    cleaned_text = re.sub(r'[^А-Яа-яӘәІіҢңҒғҚқҰұҮүҺһӨөЁё0-9\s]', '', text)
    # Remove extra spacesa
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

# Apply the cleaning function and filter out empty messages
df['message'] = df['message'].apply(clean_text)
df = df[df['message'] != ""]
# df = df[~df['message'].str.startswith("Извините")]

# Filter out rows with fewer than 5 words
df = df[df['message'].apply(lambda x: len(x.split()) >= 8)]
df
# Out:
#                    date                                            message  \
# 2   2024-10-27T18:50:04  1 2 болмели кв керек еди узак мерзимге семейны...
# 7   2024-10-23T21:18:10  Здравствуйте срочно нужна 1 комнатная квартира...
# 16  2024-09-27T15:22:44  Срочно сниму квартиру одну комнату шестом мик ...
# 18  2024-09-27T14:15:18  6 мкр бір бөлмелі квартира керек маған тез ара...
# 31  2024-09-21T21:17:53  Саламатсыздарма ұзақ мерзімге кв керек жас отб...
# 32  2024-09-21T15:00:44  Сәлеметсіздер ме 2 болмелі кв керекұзақ мерзім...
# 37  2024-09-20T15:16:19    Квартира керек 15 мкр 5060 мыңға 1 бөлеме керек
# 39  2024-09-19T11:59:23  Сниму квартиру в районе сахзаводана длительный...
# 40  2024-09-19T11:45:18  Подселение в 2х комнатную кв Проживание с ХОЗЯ...
# 45  2024-09-08T22:21:26  Здравствуйтепомогу с поиском квартиры по вашем...
# 46  2024-09-04T21:54:05             Сниму 12комнкв в 15 мкр на долгий срок
# 60  2024-04-06T07:46:24  Подселение в 2х комнатную кв Проживание с ХОЗЯ...
#
#                                          channel_name
# 2   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 7   ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 16  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 18  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 31  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 32  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 37  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 39  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 40  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 45  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 46  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ
# 60  ТАРАЗ КВАРТИРА ВРЕМЯНКА ДОМ СДАМ СНИМУ ПОДСЕЛЕНИЕ

# %%
df.to_csv('all_csv/Taraz.csv')
