# %%
import pandas as pd
import re

# %%
df = pd.read_csv('all_csv/Almaty_all.csv')
df
# Out:
#                       date                                            message  \
# 0      2024-10-31T19:19:02  Ищем на подселение 1 девушку. Квартира 3 комна...
# 1      2024-10-31T18:32:46  Всем привет, ищу 1-2 девочку к себе на подселе...
# 2      2024-10-31T18:23:14  Алма Сити 5, екы жыгыт ыздеймыз поселениеге, 5...
# 3      2024-10-31T17:43:32  СДУға жақын жерде орналасқан коттедж үй жалға ...
# 4      2024-10-31T16:42:10  📌 ищем одну девушку на подселение в однокомнат...
# ...                    ...                                                ...
# 51379  2022-08-30T01:11:14  5-комнатная квартира, 200 м², 13/16 этаж\r\n\r...
# 51380  2022-08-30T01:11:13  2-комнатная квартира, 47 м², 3/4 этаж\r\n\r\nР...
# 51381  2022-08-30T01:11:09  2-комнатная квартира, 45 м², 1/4 этаж\r\n\r\nР...
# 51382  2022-08-30T01:11:08  1-комнатная квартира, 41 м², 5/5 этаж\r\n\r\nР...
# 51383  2022-08-30T01:11:07  2-комнатная квартира, 45 м², 4/4 этаж\r\n\r\nР...
#
#             channel_name
# 0          SDU [housing]
# 1          SDU [housing]
# 2          SDU [housing]
# 3          SDU [housing]
# 4          SDU [housing]
# ...                  ...
# 51379  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51380  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51381  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51382  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51383  ПОДСЕЛЕНИЕ АЛМАТЫ
#
# [51384 rows x 3 columns]

# %%
# Function to clean each message
def clean_text(text):
    # Keep only Cyrillic letters, numbers, and spaces
    cleaned_text = re.sub(r'[^А-Яа-яӘәІіҢңҒғҚқҰұҮүҺһӨөЁё0-9\s]', '', text)
    # Remove extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

# Apply the cleaning function and filter out empty messages
df['message'] = df['message'].apply(clean_text)
df = df[df['message'] != ""]
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19040\934804152.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['message'] = df['message'].apply(clean_text)
#                       date                                            message  \
# 0      2024-10-31T19:19:02  Ищем на подселение 1 девушку Квартира 3 комнат...
# 1      2024-10-31T18:32:46  Всем привет ищу 12 девочку к себе на подселени...
# 2      2024-10-31T18:23:14  Алма Сити 5 екы жыгыт ыздеймыз поселениеге 50к...
# 3      2024-10-31T17:43:32  СДУға жақын жерде орналасқан коттедж үй жалға ...
# 4      2024-10-31T16:42:10  ищем одну девушку на подселение в однокомнатну...
# ...                    ...                                                ...
# 51379  2022-08-30T01:11:14  5комнатная квартира 200 м 1316 этаж Район Меде...
# 51380  2022-08-30T01:11:13  2комнатная квартира 47 м 34 этаж Район Алмалин...
# 51381  2022-08-30T01:11:09  2комнатная квартира 45 м 14 этаж Район Бостанд...
# 51382  2022-08-30T01:11:08  1комнатная квартира 41 м 55 этаж Район Медеуск...
# 51383  2022-08-30T01:11:07  2комнатная квартира 45 м 44 этаж Район Алмалин...
#
#             channel_name
# 0          SDU [housing]
# 1          SDU [housing]
# 2          SDU [housing]
# 3          SDU [housing]
# 4          SDU [housing]
# ...                  ...
# 51379  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51380  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51381  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51382  ПОДСЕЛЕНИЕ АЛМАТЫ
# 51383  ПОДСЕЛЕНИЕ АЛМАТЫ
#
# [51180 rows x 3 columns]

# %%
df.sort_values(by='date', ascending=False)
# Out:
#                       date                                            message  \
# 0      2024-10-31T19:19:02  Ищем на подселение 1 девушку Квартира 3 комнат...
# 13254  2024-10-31T19:13:00  СДАМ В АРЕНДУ КОМНАТУ В 3Х КОМНАТНОЙ КВ ОДНОЙ ...
# 13255  2024-10-31T19:12:43  Ищу на подселение 3 девушек Квартира 2х комнат...
# 34910  2024-10-31T19:03:39  Подселение барамын 2 курс студентпін зиянды іш...
# 34911  2024-10-31T18:59:15  Срочно Возьму на подселение 2х или одну девушк...
# ...                    ...                                                ...
# 44363  2020-05-24T16:59:00  емейная пара ищет 12 комнатную квартиру в алма...
# 44364  2020-05-24T10:01:30  Ищу 2х комнатную квартиру со всеми удобствами ...
# 44365  2020-05-24T08:30:22  Ищем на подселение 2 девушек Добросовестную лю...
# 44366  2020-05-23T23:39:43  Ищу девушку на подселение в 3х комнатную кварт...
# 44367  2020-05-23T23:38:10  Сдаётся комната на подселение 1 девушке без вр...
#
#                                             channel_name
# 0                                          SDU [housing]
# 13254                     Аренда Жилья.Подселение Алматы
# 13255                     Аренда Жилья.Подселение Алматы
# 34910                             Аренда квартира Алматы
# 34911                             Аренда квартира Алматы
# ...                                                  ...
# 44363  Квартиры Алматы  Аренда квартир Алматы  Поиск ...
# 44364  Квартиры Алматы  Аренда квартир Алматы  Поиск ...
# 44365  Квартиры Алматы  Аренда квартир Алматы  Поиск ...
# 44366  Квартиры Алматы  Аренда квартир Алматы  Поиск ...
# 44367  Квартиры Алматы  Аренда квартир Алматы  Поиск ...
#
# [51180 rows x 3 columns]
